# %%
#import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import RMSprop
from keras.utils import np_utils
import keras
import numpy as np

print(tensorflow.__version__)
print(keras.__version__)

classes = ["monkey","boar","crow"]
num_classes = len(classes)
image_size = 50

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./animal.npy", allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    #opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = RMSprop(lr=0.0001, decay=1e-6)
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./animal_cnn.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])
# Out:
# 2.4.1
# 2.2.4

# %%
if __name__ == "__main__":
    main()
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 112ms/step - loss: 1.1215 - accuracy: 0.3140
# Epoch 2/100
# 15/15 [==============================] - 2s 108ms/step - loss: 1.0926 - accuracy: 0.3695
# Epoch 3/100
# 15/15 [==============================] - 2s 105ms/step - loss: 1.0778 - accuracy: 0.4062
# Epoch 4/100
# 15/15 [==============================] - 2s 112ms/step - loss: 1.0867 - accuracy: 0.4024
# Epoch 5/100
# 15/15 [==============================] - 2s 109ms/step - loss: 1.0343 - accuracy: 0.4394
# Epoch 6/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.9985 - accuracy: 0.4896
# Epoch 7/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.9996 - accuracy: 0.5124
# Epoch 8/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.9864 - accuracy: 0.5385
# Epoch 9/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.9209 - accuracy: 0.5831
# Epoch 10/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.9288 - accuracy: 0.5974
# Epoch 11/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.8851 - accuracy: 0.5813
# Epoch 12/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.9030 - accuracy: 0.5929
# Epoch 13/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.8738 - accuracy: 0.6016
# Epoch 14/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.8617 - accuracy: 0.5893
# Epoch 15/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.8613 - accuracy: 0.6054
# Epoch 16/100
# 15/15 [==============================] - 2s 117ms/step - loss: 0.8091 - accuracy: 0.6073
# Epoch 17/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.8528 - accuracy: 0.6343
# Epoch 18/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.7382 - accuracy: 0.6905
# Epoch 19/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.7601 - accuracy: 0.6741
# Epoch 20/100
# 15/15 [==============================] - 2s 118ms/step - loss: 0.7175 - accuracy: 0.7124
# Epoch 21/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.8151 - accuracy: 0.6826
# Epoch 22/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.6742 - accuracy: 0.7271
# Epoch 23/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.7237 - accuracy: 0.6965
# Epoch 24/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.6950 - accuracy: 0.6936
# Epoch 25/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.6953 - accuracy: 0.7040
# Epoch 26/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.6938 - accuracy: 0.7027
# Epoch 27/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.7521 - accuracy: 0.7068
# Epoch 28/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.6449 - accuracy: 0.7266
# Epoch 29/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.5970 - accuracy: 0.7423
# Epoch 30/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.6690 - accuracy: 0.6760
# Epoch 31/100
# 15/15 [==============================] - 2s 103ms/step - loss: 0.7049 - accuracy: 0.7311
# Epoch 32/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.5764 - accuracy: 0.7671
# Epoch 33/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.6616 - accuracy: 0.7082
# Epoch 34/100
# 15/15 [==============================] - 2s 121ms/step - loss: 0.6452 - accuracy: 0.7169
# Epoch 35/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.5856 - accuracy: 0.7629
# Epoch 36/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5248 - accuracy: 0.8115
# Epoch 37/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.6770 - accuracy: 0.7317
# Epoch 38/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.5462 - accuracy: 0.7890
# Epoch 39/100
# 15/15 [==============================] - 2s 118ms/step - loss: 0.4968 - accuracy: 0.8010
# Epoch 40/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.5298 - accuracy: 0.7866
# Epoch 41/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.5507 - accuracy: 0.7656
# Epoch 42/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.5686 - accuracy: 0.7493
# Epoch 43/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.5526 - accuracy: 0.7641
# Epoch 44/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.5452 - accuracy: 0.7855
# Epoch 45/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.4906 - accuracy: 0.8039
# Epoch 46/100
# 15/15 [==============================] - 2s 116ms/step - loss: 0.5354 - accuracy: 0.7793
# Epoch 47/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.4123 - accuracy: 0.8427
# Epoch 48/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4441 - accuracy: 0.8295
# Epoch 49/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4450 - accuracy: 0.8298
# Epoch 50/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.4322 - accuracy: 0.8356
# Epoch 51/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.4066 - accuracy: 0.8603
# Epoch 52/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.4535 - accuracy: 0.8259
# Epoch 53/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.3915 - accuracy: 0.8485
# Epoch 54/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.3973 - accuracy: 0.8495
# Epoch 55/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.4119 - accuracy: 0.8433
# Epoch 56/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.3785 - accuracy: 0.8778
# Epoch 57/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.3537 - accuracy: 0.8760
# Epoch 58/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.3954 - accuracy: 0.8370
# Epoch 59/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.3238 - accuracy: 0.8776
# Epoch 60/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.3707 - accuracy: 0.8503
# Epoch 61/100
# 15/15 [==============================] - 2s 116ms/step - loss: 0.3339 - accuracy: 0.8772
# Epoch 62/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.3386 - accuracy: 0.8652
# Epoch 63/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.3943 - accuracy: 0.8373
# Epoch 64/100
# 15/15 [==============================] - 2s 117ms/step - loss: 0.3129 - accuracy: 0.8855
# Epoch 65/100
# 15/15 [==============================] - 2s 114ms/step - loss: 0.3545 - accuracy: 0.8505
# Epoch 66/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.3524 - accuracy: 0.8534
# Epoch 67/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.2639 - accuracy: 0.9094
# Epoch 68/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2506 - accuracy: 0.9099
# Epoch 69/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2855 - accuracy: 0.9070
# Epoch 70/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.2903 - accuracy: 0.9126
# Epoch 71/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2518 - accuracy: 0.9276
# Epoch 72/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2927 - accuracy: 0.9072
# Epoch 73/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.2513 - accuracy: 0.9056
# Epoch 74/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.2209 - accuracy: 0.9155
# Epoch 75/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.2670 - accuracy: 0.9172
# Epoch 76/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2485 - accuracy: 0.8964
# Epoch 77/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.2351 - accuracy: 0.9215
# Epoch 78/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.2061 - accuracy: 0.9277
# Epoch 79/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2585 - accuracy: 0.8938
# Epoch 80/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1909 - accuracy: 0.9274
# Epoch 81/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2006 - accuracy: 0.9374
# Epoch 82/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.1660 - accuracy: 0.9524
# Epoch 83/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.2134 - accuracy: 0.9303
# Epoch 84/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.1651 - accuracy: 0.9580
# Epoch 85/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.1680 - accuracy: 0.9571
# Epoch 86/100
# 15/15 [==============================] - 2s 108ms/step - loss: 0.1656 - accuracy: 0.9471
# Epoch 87/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.1813 - accuracy: 0.9314
# Epoch 88/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.1306 - accuracy: 0.9554
# Epoch 89/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.1424 - accuracy: 0.9622
# Epoch 90/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.2698 - accuracy: 0.9141
# Epoch 91/100
# 15/15 [==============================] - 2s 102ms/step - loss: 0.1489 - accuracy: 0.9486
# Epoch 92/100
# 15/15 [==============================] - 2s 104ms/step - loss: 0.1378 - accuracy: 0.9465
# Epoch 93/100
# 15/15 [==============================] - 1s 100ms/step - loss: 0.1599 - accuracy: 0.9551
# Epoch 94/100
# 15/15 [==============================] - 2s 106ms/step - loss: 0.1226 - accuracy: 0.9575
# Epoch 95/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.1119 - accuracy: 0.9732
# Epoch 96/100
# 15/15 [==============================] - 2s 103ms/step - loss: 0.1451 - accuracy: 0.9392
# Epoch 97/100
# 15/15 [==============================] - 2s 102ms/step - loss: 0.1186 - accuracy: 0.9745
# Epoch 98/100
# 15/15 [==============================] - 2s 103ms/step - loss: 0.1341 - accuracy: 0.9590
# Epoch 99/100
# 15/15 [==============================] - 2s 117ms/step - loss: 0.1152 - accuracy: 0.9610
# Epoch 100/100
# 15/15 [==============================] - 2s 105ms/step - loss: 0.0865 - accuracy: 0.9784
# 5/5 [==============================] - 0s 28ms/step - loss: 1.3157 - accuracy: 0.6333
# Test Loss:  1.3156943321228027
# Test Accuracy:  0.6333333253860474
